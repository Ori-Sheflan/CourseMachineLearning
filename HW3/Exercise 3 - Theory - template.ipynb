# %% [markdown]
# # Machine learning Exercise 3
# ## Part 1 -  Probability theory part

# %% [markdown]
# by Segal & Millis

# %% [markdown]
# ### Q1 - MLE for Poisson.
# Given a random sample {𝑥1, 𝑥2, … , 𝑥𝑛}, derive the maximum likelihood estimator 𝜆 of the Poisson distribution.
#
# $$
# P\big(x,\lambda \big) = \frac{e^{-\lambda} \lambda^x}{x!}
# $$

# %% [markdown]
# <br><br><br>
# <br><br><br>
# <br><br><br>

# %% [markdown]
# ### Q2 - A radar at the beach is used to detect ships.
# Ships are located in one of four zones: 𝐴, 𝐵, 𝐶 and 𝐷.
# The probability of detection per zone is 0.75, 0.5, 0.3, 0.4 for 𝐴, 𝐵, 𝐶,𝐷 respectively.
# The probability of being at a specific zone is 0.4, 0.2, 0.3, 0.1 for 𝐴, 𝐵, 𝐶,𝐷, respectively.

# %% [markdown]
# ##### a. What is the probability that a ship will be detected?

# %% [markdown]
# ##### b. Given that a ship is detected, what is the probability that it was in zone 𝐶?

# %% [markdown]
# ##### c. Given that a ship is detected, what is the probability that it was in zone 𝐵?

# %% [markdown]
# <br><br><br>
# <br><br><br>
# <br><br><br>

# %% [markdown]
# ### Q3 - Find 3 random variables 𝑋, 𝑌, 𝐶 such that:
# a. 𝑋 ⊥ 𝑌 | 𝐶 – (𝑋 and 𝑌 are independent given 𝐶.)
# b. 𝑋 and 𝑌 are not independent.
# c. 𝑋, 𝑌 take integer values such that 1 ≤ 𝑋, 𝑌 ≤ 10 and 𝐶 is binary.
# d. The following conditions hold:
#
#     i. 𝑃(1 ≤ 𝑋 ≤ 5) = 0.3
#     ii. 𝑃(1 ≤ 𝑌 ≤ 5) = 0.3
#     iii. 𝑃(𝐶 = 0) = 0.5

# %% [markdown]
# <br><br><br>
# <br><br><br>
# <br><br><br>

# %% [markdown]
# ### Q4 - The probability of having a decent meal in Karnaf is 0.65.

# %% [markdown]
# ##### a. What is the probability of having 3 descent meals in a week (5 days)?

# %% [markdown]
# ##### b. What is the probability of having at least 2 descent meals in a week?

# %% [markdown]
# ##### c. A class of 300 students recorded the number of descent meals they had during a specific week.
# They averaged their results. What do you expect the value of that
#     average to be?

# %% [markdown]
# <br><br><br>
# <br><br><br>
# <br><br><br>

# %% [markdown]
# ### Q5 - Bivariate Normal Distribution
#
# you are given a dataset of 1,000 (𝑥1, 𝑥2) points drawn from a Bivariate Normal distribution with unknown parameters (data/bivariate_normal_data.csv).

# %% [markdown]
# ##### a. Estimate the distribution parameters using the following (these are the MLE parameters):
#
# $$ \mu_i = \frac{1}{N} \sum_{k=1}^{N}x_i^{(k)} $$
# $$ \sigma_i = \frac{1}{N} \sum_{k=1}^{N}{\big( x_i^{(k)} - \mu \big)}^2 $$
# $$ \rho = \frac{1}{N} \sum_{k=1}^{N} \big( x_1^{(k)} - \mu_1 \big) \cdot \big( x_2^{(k)} - \mu_2 \big)$$

# %% [markdown]
# ##### b. Using the parameters you found:
# - plot the distribution in 3d
# - mark on the plot the points from the dataset we provided you that correspond to some narrow equiprobable range.
# - For example, given the range 𝑃(0.14 ≤ 𝑋 ≤ 0.15):
# <image >

# %% [markdown]
# ![3dplot.PNG](attachment:3dplot.PNG)
