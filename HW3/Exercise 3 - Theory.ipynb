# %% [markdown]
# # Machine learning Exercise 3
# ## Part 1 -  Probability theory part

# %% [markdown]
# ### Q1 - MLE for Poisson.
# Given a random sample {𝑥1, 𝑥2, … , 𝑥𝑛}, derive the maximum likelihood estimator 𝜆 of the Poisson distribution.
#
# $$
# P\big(x,\lambda \big) = \frac{e^{-\lambda} \lambda^x}{x!}
# $$

# %% [markdown]
# We will look at $ L(\theta) = ln P(D|\theta) : $
#
#
# $
# L(\theta) = \\
# = ln P(D|\theta) = \\
# = ln \bigg( \Pi_{j=1}^{n} e^{-\lambda} \frac{\lambda^{X_j}}{x_j!} \bigg) = \\
# = \Sigma_{j=1}^{n}  ln \big( e^{-\lambda} \frac{\lambda^{X_j}}{x_j!} \big) = \\
# = \Sigma_{j=1}^{n} \bigg( ln(e^{-\lambda}) + ln(\lambda^{x_j}) - ln(X_j!)  \bigg) = \\
# = \Sigma_{j=1}^{n} \bigg( -\lambda +x_jln\lambda - ln(x_j!)    \bigg) = \\
# = -n\lambda + ln \lambda \Sigma_{j=1}^{n}x_j  - \Sigma_{j=1}^{n} ln(x_j!) \\
# $
#
# $
# \frac{dL(\theta)}{d\lambda} = -n + \frac{1}{\lambda}\Sigma_{j=1}^{n}x_j = 0 \space\space\space \Rightarrow \space\space\space \lambda = \frac{1}{n} \Sigma_{j=1}^{n}x_j
# $

# %% [markdown]
# <br><br><br>
# <br><br><br>
# <br><br><br>

# %% [markdown]
# ### Q2 - A radar at the beach is used to detect ships.
# Ships are located in one of four zones: 𝐴, 𝐵, 𝐶 and 𝐷.
# The probability of detection per zone is 0.75, 0.5, 0.3, 0.4 for 𝐴, 𝐵, 𝐶,𝐷 respectively.
# The probability of being at a specific zone is 0.4, 0.2, 0.3, 0.1 for 𝐴, 𝐵, 𝐶,𝐷, respectively.

# %% [markdown]
# ##### a. What is the probability that a ship will be detected?

# %% [markdown]
# $
# P(detected) = P(detected|A) P(A) + P(detected|B)P(B) + P(detected|C)P(C) + P(detected|D)P(D) = \\
# = 0.75 \cdot 0.4 + 0.5 \cdot 0.2 + 0.3 \cdot 0.3 + 0.4 \cdot 0.1 = 0.53
# $

# %% [markdown]
# ##### b. Given that a ship is detected, what is the probability that it was in zone 𝐶?

# %% [markdown]
# $
# P(C|detected) = \frac{P(detected|C)P(C)}{P(detected)} = \frac{0.3 \cdot 0.3}{0.53} = 0.17
# $

# %% [markdown]
# ##### c. Given that a ship is detected, what is the probability that it was in zone 𝐵?

# %% [markdown]
# $
# P(B|detected) = \frac{P(detected|B)P(B)}{P(detected)} = \frac{0.5 \cdot 0.2}{0.53} = 0.189
# $

# %% [markdown]
# <br><br><br>
# <br><br><br>
# <br><br><br>

# %% [markdown]
# ### Q3 - Find 3 random variables 𝑋, 𝑌, 𝐶 such that:
# a. 𝑋 ⊥ 𝑌 | 𝐶 – (𝑋 and 𝑌 are independent given 𝐶.)
# b. 𝑋 and 𝑌 are not independent.
# c. 𝑋, 𝑌 take integer values such that 1 ≤ 𝑋, 𝑌 ≤ 10 and 𝐶 is binary.
# d. The following conditions hold:
#
#     i. 𝑃(1 ≤ 𝑋 ≤ 5) = 0.3
#     ii. 𝑃(1 ≤ 𝑌 ≤ 5) = 0.3
#     iii. 𝑃(𝐶 = 0) = 0.5

# %% [markdown]
# Let's define `C` as a uniform binary variable:
#
# $
# C \sim U\big(0,1\big) \\
# P\big(C=0\big) = 0.5 \\
# P\big(C=1\big) = 0.5
# $

# %% [markdown]
# Let's Define X as follows:
# $
# X \in \{1,2,3...10\}  \\
# P\big( 1 \leq X \leq 10 \space \big| \space C=0\big) = 0  \\
# P\big( 1 \leq X \leq 5 \space \big| \space C=1\big) = 0.12  \\
# P\big( 6 \leq X \leq 9 \space \big| \space C=1\big) = 0.2  \\
# P\big( X=10 \space \big| \space C=1\big) = 0.6 \\
# $
#
# Let's Define Y as follows:
# $
# Y \in \{1,2,3...10\}  \\
# P\big( 1 \leq Y \leq 10 \space \big| \space C=1\big) = 0  \\
# P\big( 1 \leq Y \leq 5 \space \big| \space C=0\big) = 0.12  \\
# P\big( 6 \leq Y \leq 9 \space \big| \space C=0\big) = 0.2  \\
# P\big( Y=10 \space \big| \space C=0\big) = 0.6 \\
# $
#
# Thus X and Y are dependent(not independent)!
# Because, For example, $P(X=10) < Pr(X=10 | Y=10)$ .
#
#
# Keepiing with the conditions:
# $
# P\big( 1 \leq X \leq 5) \space\space = \space\space   P\big( 1 \leq X \leq 5 \space \big| \space C=0\big)\cdot P(C=0) + P\big( 1 \leq X \leq 5 \space \big| \space C=1\big)\cdot P(C=1) \space\space = \space\space  0 \cdot 0.5 + (0.12 \cdot 5) \cdot 0.5 \space\space = \space\space 0.3  \\
# P\big( 1 \leq Y \leq 5) \space\space = \space\space P\big( 1 \leq Y \leq 5 \space \big| \space C=0\big)\cdot P(C=0) + P\big( 1 \leq Y \leq 5 \space \big| \space C=1\big)\cdot P(C=1) \space\space = \space\space (0.12 \cdot 5) \cdot 0.5 + 0 \cdot 0.5 \space\space = \space\space 0.3 \\
# P\big(C=0\big) \space\space = \space\space 0.5
# $
#
# Done!

# %% [markdown]
# <br><br><br>
# <br><br><br>
# <br><br><br>

# %% [markdown]
# ### Q4 - The probability of having a decent meal in Karnaf is 0.65.

# %% [markdown]
# ##### a. What is the probability of having 3 descent meals in a week (5 days)?

# %% [markdown]
# $
# P(x=3) = {5 \choose 3} 0.65^3 \cdot 0.35^2 = 0.34
# $

# %% [markdown]
# ##### b. What is the probability of having at least 2 descent meals in a week?

# %% [markdown]
# $
# P(2 \leq x) = \\
# = 1 - \bigg( P(x=0) + P(x=1) \bigg) =   \\
# = 1 - \bigg( {5 \choose 0} 0.65^0 \cdot 0.35^5 + {5 \choose 1} 0.65^1 \cdot 0.35^4 \bigg) = \\
# = 1 - \big(0.0053 + 0.049\big) = 0.946
# $

# %% [markdown]
# ##### c. A class of 300 students recorded the number of descent meals they had during a specific week.
# They averaged their results. What do you expect the value of that
#     average to be?

# %% [markdown]
# let's note `X` as total number of decent meals.
# $ X \sim Bin(5,0.65) $
#
# Average of Number of descemt meals = $\frac{Student_1 + student_2 + ... + Student_{300}}{300}\ =$
#
# And as we make our sample size larger it should be close to the mean for a single sample which is
#
# $\Rightarrow E(X) = n \cdot p = 5 \cdot 0.65 = 3.25 $

# %% [markdown]
# <br><br><br>
# <br><br><br>
# <br><br><br>

# %% [markdown]
# ### Q5 - Bivariate Normal Distribution
#
# you are given a dataset of 1,000 (𝑥1, 𝑥2) points drawn from a Bivariate Normal distribution with unknown parameters (data/bivariate_normal_data.csv).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from scipy.stats import multivariate_normal

# %% [markdown]
# ##### a. Estimate the distribution parameters using the following (these are the MLE parameters):
#
# $$ \mu_i = \frac{1}{N} \sum_{k=1}^{N}x_i^{(k)} $$
# $$ \sigma_i = \frac{1}{N} \sum_{k=1}^{N}{\big( x_i^{(k)} - \mu \big)}^2 $$
# $$ \rho = \frac{1}{N} \sum_{k=1}^{N} \big( x_1^{(k)} - \mu_1 \big) \cdot \big( x_2^{(k)} - \mu_2 \big)$$

# %%
df = pd.read_csv('data/bivariate_normal_data.csv',names=['x1','x2'],header=0)
df.head()

μ = df.mean() # or df.sum(axis=0)/len(df)
σ = np.square(df - μ).mean()  # or df.std() 
ρ = ((df.x1 - μ[0]) * (df.x2 - μ[1])).mean()

print('μ = ', μ.values)
print('σ = ', σ.values)
print('ρ = ', ρ)
# Out:
# μ =  [ 0.51113139 -2.01599143]
# σ =  [0.99302132 0.99689616]
# ρ =  0.6619576045042657

# %% [markdown]
# ##### b. Using the parameters you found:
# - plot the distribution in 3d
# - mark on the plot the points from the dataset we provided you that correspond to some narrow equiprobable range.
# - For example, given the range 𝑃(0.14 ≤ 𝑋 ≤ 0.15):
# <image >

# %% [markdown]
# ![3dplot.PNG](attachment:3dplot.PNG)

# %%
# Sort values
x = df.x1.sort_values()
y = df.x2.sort_values()


# Surface - Create grid and multivariate normal
X, Y = np.meshgrid(np.linspace(x.min(),x.max(),500),np.linspace(y.min(),y.max(),500))
pos = np.empty(X.shape + (2,))
pos[:, :, 0] = X
pos[:, :, 1] = Y
Z = multivariate_normal(μ.values, np.square(σ.values)).pdf(pos)

# points - Create z values by range
x_min,x_max = 0.14,0.15
xy = np.empty( x.shape + (2,) )
xy[:,0] = x
xy[:,1] = y
z = multivariate_normal(μ.values, np.square(σ.values)).pdf(xy)
x_range = (x_min <= x) & (x <= x_max)

#Make a 3D plot
fig = plt.figure(figsize=(14,8))
ax = fig.gca(projection='3d')
ax.plot_surface(X, Y, Z,cmap='viridis',linewidth=0)
ax.plot(x[x_range], y[x_range], z[x_range], marker='.', linestyle='None', label='Label', color='red', zorder=10,alpha=0.2)
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
ax.set_zlabel('Z axis')
# ax.view_init(elev=30,azim=200) # change view of the 3D plot
plt.show()
